# %%
import numpy as np
import pandas as pd
import joblib
df_pure = joblib.load("pure.job")
df_mixed = joblib.load("mixed.job")
df_states = joblib.load("ghz+sep.job")

# %%
df_pure
# Out:
#               0    1         2         3         4         5         6  \
# 0      0.245802  0.0 -0.030823 -0.023831  0.382758 -0.181260 -0.065570
# 1      0.020670  0.0 -0.040674 -0.064515  0.031250 -0.003254 -0.071650
# 2      0.008397  0.0 -0.030964 -0.056298 -0.047925 -0.042794  0.001882
# 3      0.018756  0.0 -0.000101 -0.030422 -0.065151  0.023854  0.039042
# 4      0.422774  0.0  0.127692 -0.127844 -0.169581 -0.062382  0.383668
# ...         ...  ...       ...       ...       ...       ...       ...
# 19995  0.716615  0.0  0.208997  0.285354 -0.213612  0.130642 -0.114320
# 19996  0.011590  0.0 -0.000123 -0.000146 -0.055544 -0.091474 -0.000560
# 19997  0.239433  0.0  0.224706 -0.109066  0.088561  0.233549 -0.174130
# 19998  0.181330  0.0 -0.037029 -0.256242  0.153531  0.056768  0.048869
# 19999  0.177687  0.0 -0.165116  0.173227 -0.238904 -0.013998 -0.129910
#
#               7         8         9  ...        23        24        25  \
# 0     -0.014380 -0.030823  0.023831  ... -0.070746 -0.065570  0.014380
# 1     -0.091134 -0.040674  0.064515  ... -0.149063 -0.071650  0.091134
# 2     -0.008184 -0.030964  0.056298  ...  0.056298  0.001882  0.008184
# 3      0.105548 -0.000101  0.030422  ... -0.416297  0.039042 -0.105548
# 4     -0.177585  0.127692  0.127844  ...  0.127844  0.383668  0.177585
# ...         ...       ...       ...  ...       ...       ...       ...
# 19995 -0.046959  0.208997 -0.285354  ...  0.034839 -0.114320  0.046959
# 19996  0.001670 -0.000123  0.000146  ... -0.012422 -0.000560 -0.001670
# 19997 -0.164338  0.224706  0.109066  ...  0.109066 -0.174130  0.164338
# 19998 -0.228551 -0.037029  0.256242  ... -0.208812  0.048869  0.228551
# 19999  0.121228 -0.165116 -0.173227  ... -0.173227 -0.129910 -0.121228
#
#              26        27        28        29        30   31  entangled
# 0      0.009616  0.004554 -0.091500  0.070746  0.018333  0.0          0
# 1      0.425434  0.044302 -0.093977  0.149063  0.650174  0.0          0
# 2      0.047925 -0.042794  0.030964 -0.056298  0.008397  0.0          1
# 3     -0.171409 -0.062759 -0.001382  0.416297  0.675245  0.0          0
# 4      0.169581 -0.062382 -0.127692 -0.127844  0.422774  0.0          1
# ...         ...       ...       ...       ...       ...  ...        ...
# 19995 -0.052040 -0.031827  0.025516 -0.034839  0.021314  0.0          0
# 19996 -0.000015  0.000025 -0.010500  0.012422  0.000268  0.0          0
# 19997 -0.088561  0.233549 -0.224706 -0.109066  0.239433  0.0          1
# 19998  0.312993 -0.115730 -0.030175  0.208812  0.301240  0.0          0
# 19999  0.238904 -0.013998  0.165116  0.173227  0.177687  0.0          1
#
# [20000 rows x 33 columns]

# %%
import seaborn as sns

corr = df_pure.corr()
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns)
# Out:
# <AxesSubplot:>

# %%
corr = df_mixed.corr()
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns)
# Out:
# <AxesSubplot:>

# %%
corr = df_states.corr()
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns)
# Out:
# <AxesSubplot:>
